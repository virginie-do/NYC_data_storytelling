# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Let's take a first look at the data.

# %%
df = pd.read_csv('data/311_test.csv')
df.head(5)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    36335488  06/01/2017 12:00:00 AM  06/23/2017 12:00:00 AM  DOHMH
# 1    36334571  06/01/2017 12:00:00 AM  06/22/2017 12:00:00 AM  DOHMH
# 2    36334446  06/01/2017 12:00:00 AM  06/21/2017 12:00:00 AM  DOHMH
# 3    36332405  06/01/2017 12:00:00 AM  06/22/2017 12:00:00 AM  DOHMH
# 4    36332388  06/01/2017 12:00:00 AM  06/21/2017 12:00:00 AM  DOHMH
#
#                                Agency Name               Complaint Type  \
# 0  Department of Health and Mental Hygiene                       Rodent
# 1  Department of Health and Mental Hygiene                       Rodent
# 2  Department of Health and Mental Hygiene  Unsanitary Pigeon Condition
# 3  Department of Health and Mental Hygiene                       Rodent
# 4  Department of Health and Mental Hygiene                       Rodent
#
#        Descriptor            Location Type Incident Zip    Incident Address  \
# 0    Rat Sighting      1-2 Family Dwelling        10474   624 COSTER STREET
# 1    Rat Sighting               Vacant Lot        11215       224 12 STREET
# 2    Pigeon Waste      Commercial Building        10303  2501 FOREST AVENUE
# 3    Rat Sighting               Vacant Lot        11215       224 12 STREET
# 4  Mouse Sighting  3+ Family Apt. Building        11105     21-24 31 STREET
#
#                     ...                    Bridge Highway Name  \
# 0                   ...                                    NaN
# 1                   ...                                    NaN
# 2                   ...                                    NaN
# 3                   ...                                    NaN
# 4                   ...                                    NaN
#
#   Bridge Highway Direction Road Ramp Bridge Highway Segment Garage Lot Name  \
# 0                      NaN       NaN                    NaN             NaN
# 1                      NaN       NaN                    NaN             NaN
# 2                      NaN       NaN                    NaN             NaN
# 3                      NaN       NaN                    NaN             NaN
# 4                      NaN       NaN                    NaN             NaN
#
#   Ferry Direction Ferry Terminal Name   Latitude  Longitude  \
# 0             NaN                 NaN  40.812797 -73.886981
# 1             NaN                 NaN  40.668242 -73.989604
# 2             NaN                 NaN  40.626336 -74.174961
# 3             NaN                 NaN  40.668242 -73.989604
# 4             NaN                 NaN  40.777379 -73.909192
#
#                                   Location
# 0   (40.81279663744078, -73.8869808964065)
# 1  (40.66824162997938, -73.98960394471317)
# 2  (40.62633610844385, -74.17496135020113)
# 3  (40.66824162997938, -73.98960394471317)
# 4  (40.777379055532506, -73.9091923175842)
#
# [5 rows x 53 columns]

# %% [markdown]
# # We can see the data is full of missing values. Let's clean it up!

# %%
df.isnull().sum()

# %%
delete_columns = ["Intersection Street 1", "Intersection Street 2", "Address Type", "Landmark", "Facility Type",\
                  "Status", "X Coordinate (State Plane)", "Y Coordinate (State Plane)", "Park Facility Name",\
                  "Park Borough", "School Name", "School Number", "School Region", "School Code",\
                  "School Phone Number", 
                  "School Address", "School City", "School State", "School Zip", "School Not Found",\
                  "School or Citywide Complaint", "Vehicle Type", "Taxi Company Borough", "Taxi Pick Up Location",\
                  "Bridge Highway Name", "Bridge Highway Direction", "Road Ramp", "Bridge Highway Segment",\
                  "Garage Lot Name", "Ferry Direction", "Ferry Terminal Name","Due Date", \
                  "Resolution Action Updated Date","Incident Address","Street Name","Cross Street 1","Cross Street 2",\
                  "Location Type","Resolution Description"]

df.drop(delete_columns, axis=1, inplace=True)
df.shape
# Out:
# (14812, 14)

# %%
#Drop NAs in several categories and print new null sums
df = df.dropna(subset=['Latitude',"Longitude","Complaint Type", "Incident Zip"], how='any')
df.isnull().sum()
# Out:
# Unique Key            0
# Created Date          0
# Closed Date        1215
# Agency                0
# Agency Name           0
# Complaint Type        0
# Descriptor          167
# Incident Zip          0
# City                  1
# Community Board       0
# Borough               0
# Latitude              0
# Longitude             0
# Location              0
# dtype: int64

# %%
#Change incident_zip column datatype from float to str
#to map with GeoJSON
df['Incident Zip'] = df['Incident Zip'].astype(int)
df['Incident Zip'] = df['Incident Zip'].astype(str)
df['Incident Zip'].dtype
# Out:
# dtype('O')

# %% [markdown]
# # Let's clean the column name syntax as well. Making queries will become easier.

# %%
#Cleaning column name syntax
df.columns = ['unique_key','created_date', 'closed_date', 'agency', 'agency_name','complaint_type',\
                    'descriptor', 'incident_zip', 'city','community_board', 'borough', 'latitude', 'longitude',\
                    'location']
df.head(5)
# Out:
#    unique_key            created_date             closed_date agency  \
# 0    36335488  06/01/2017 12:00:00 AM  06/23/2017 12:00:00 AM  DOHMH
# 1    36334571  06/01/2017 12:00:00 AM  06/22/2017 12:00:00 AM  DOHMH
# 2    36334446  06/01/2017 12:00:00 AM  06/21/2017 12:00:00 AM  DOHMH
# 3    36332405  06/01/2017 12:00:00 AM  06/22/2017 12:00:00 AM  DOHMH
# 4    36332388  06/01/2017 12:00:00 AM  06/21/2017 12:00:00 AM  DOHMH
#
#                                agency_name               complaint_type  \
# 0  Department of Health and Mental Hygiene                       Rodent
# 1  Department of Health and Mental Hygiene                       Rodent
# 2  Department of Health and Mental Hygiene  Unsanitary Pigeon Condition
# 3  Department of Health and Mental Hygiene                       Rodent
# 4  Department of Health and Mental Hygiene                       Rodent
#
#        descriptor incident_zip           city   community_board  \
# 0    Rat Sighting        10474          BRONX          02 BRONX
# 1    Rat Sighting        11215       BROOKLYN       06 BROOKLYN
# 2    Pigeon Waste        10303  STATEN ISLAND  01 STATEN ISLAND
# 3    Rat Sighting        11215       BROOKLYN       06 BROOKLYN
# 4  Mouse Sighting        11105        Astoria         01 QUEENS
#
#          borough   latitude  longitude  \
# 0          BRONX  40.812797 -73.886981
# 1       BROOKLYN  40.668242 -73.989604
# 2  STATEN ISLAND  40.626336 -74.174961
# 3       BROOKLYN  40.668242 -73.989604
# 4         QUEENS  40.777379 -73.909192
#
#                                   location
# 0   (40.81279663744078, -73.8869808964065)
# 1  (40.66824162997938, -73.98960394471317)
# 2  (40.62633610844385, -74.17496135020113)
# 3  (40.66824162997938, -73.98960394471317)
# 4  (40.777379055532506, -73.9091923175842)

# %%
df.to_csv('data/cleaned_311_test_2015.csv')
